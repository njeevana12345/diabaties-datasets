# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/jeevana/OneDrive/Desktop/diabetes (1).csv")
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
df.sample()
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1577            6      166             74              0        0  26.6
#
#       DiabetesPedigreeFunction  Age  Outcome
# 1577                     0.304   66        0

# %%
df.shape
# Out:
# (2000, 9)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
plt.figure(figsize=(10,4))   # optional: set figure size

# First subplot
plt.subplot(1, 2, 1)  # 1 row, 2 columns, plot 1
plt.plot([1,2,3], [4,5,6])
plt.title("Plot 1")

# Second subplot
plt.subplot(1, 2, 2)  # 1 row, 2 columns, plot 2
plt.plot([1,2,3], [6,5,4])
plt.title("Plot 2")

plt.tight_layout()  # adjust spacing
plt.show()

# %%
plt.figure(figsize=(10,15),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.displot(df[column])
        plt.xlabel(column,fontsize=10)
    plotnumber+=1
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 1600
# 400

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)  # increase max_iter if it warns
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
from sklearn.metrics import accuracy_score

print("Training Accuracy:", accuracy_score(y_train, model.predict(x_train)))
print("Testing Accuracy :", accuracy_score(y_test, model.predict(x_test)))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy : 1.0

# %%
X = df.drop("Outcome", axis=1)  # features
y = df["Outcome"]               # labels

# %%
x
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0               2      138             62             35        0
# 1               0       84             82             31      125
# 2               0      145              0              0        0
# 3               0      135             68             42      250
# 4               1      139             62             41      480
# ...           ...      ...            ...            ...      ...
# 1995            2       75             64             24       55
# 1996            8      179             72             42      130
# 1997            6       85             78              0        0
# 1998            0      129            110             46      130
# 1999            2       81             72             15       76
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# 1                        0.233   23        0
# ...

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression() 
LR.fit(x_train,y_train)  
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([-1.11563983e-15,  1.00000000e+00,  3.13922162e-15, ...,
#         2.20913205e-15, -1.20503533e-16,  1.00000000e+00])

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_pred)
r2score
# Out:
# 1.0

# %%
print("MSE : ",mean_squared_error(y_test,y_pred))
print("MAE : ",mean_absolute_error(y_test,y_pred))
print("RMSE : ",root_mean_squared_error(y_test,y_pred))
# Out:
# MSE :  4.806286420425533e-30
# MAE :  1.818316872236819e-15
# RMSE :  2.192324433204523e-15

# %%
# If y_pred has probabilities, convert to 0 or 1
y_pred_labels = (y_pred >= 0.5).astype(int)

from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred_labels)
print("Accuracy of Logistic Regression model is:", accuracy)
# Out:
# Accuracy of Logistic Regression model is: 1.0

# %%
# If y_pred has probabilities, convert to 0 or 1
y_pred_labels = (y_pred >= 0.5).astype(int)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_labels)
print(cm)
# Out:
# [[1050    0]
#  [   0  550]]

# %%
df['BMI'] =df['BMI'].replace(0,df['BMI'].median())
df['BloodPressure'] =df['BloodPressure'].replace(0,df['BloodPressure'].median())
df['Insulin'] =df['Insulin'].replace(0,df['Insulin'].median())
df['SkinThickness'] =df['SkinThickness'].replace(0,df['SkinThickness'].median())

# %%
plt.figure(figsize=(10,15),facecolor='white')
plotnumber=1
for column in df:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.histplot(x=df[column],hue=df['Outcome'],kde=True)
        plt.xlabel(column,fontsize=10)
        plt.ylabel('Outcome',fontsize=20)
    plotnumber+=1
plt.show()

# %%
from scipy import stats 
import statsmodels.api as sm
Glucose_pos=df[df['Outcome']==1]['Glucose']
Glucose_negative=df[df['Outcome']==0]['Glucose']

# %%
t_stat,p_val=stats.ttest_ind(Glucose_pos,Glucose_pos)
print('p-value :',p_val)
print('independentb t_test statistics:',t_stat)
if p_val<0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value : 1.0
# independentb t_test statistics: 0.0
# fail to reject null hypothesis

# %%
bp_pos = df[df['Outcome'] == 1]['BloodPressure']
bp_neg = df[df['Outcome'] == 0]['BloodPressure']
t_stat, p_val = stats.ttest_ind(bp_pos, bp_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 4.332434442926917e-15
# independent t-test statistic: 7.906717522386685
# reject null hypothesis

# %%
skin_pos = df[df['Outcome'] == 1]['SkinThickness']
skin_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %%
Pregnancies_pos= df[df['Outcome'] == 1]['SkinThickness']
Pregnancies_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
Insulin_pos= df[df['Outcome'] == 1]['SkinThickness']
Insulin_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %%
BMI_pos= df[df['Outcome'] == 1]['SkinThickness']
BMI_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %%
DiabetesPedigreeFunction_pos= df[df['Outcome'] == 1]['SkinThickness']
DiabetesPedigreeFunction_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %%
Age_pos= df[df['Outcome'] == 1]['SkinThickness']
Age_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %%
Outcome_pos= df[df['Outcome'] == 1]['SkinThickness']
Outcome_neg = df[df['Outcome'] == 0]['SkinThickness']
t_stat, p_val = stats.ttest_ind(skin_pos, skin_neg)
print('p-value:', p_val)
print('independent t-test statistic:', t_stat)
if p_val < 0.05:
    print('reject null hypothesis')
else:
    print('fail to reject null hypothesis')
# Out:
# p-value: 2.9903729132502143e-16
# independent t-test statistic: 8.243567257023205
# reject null hypothesis

# %% [markdown]
# # column name          p-value          t-test           effect
#    Glucose               1.0            0.0         Fail to reject
#    Blood Pressure        4.3324        7.9067      Reject null hypothesis
#    Skin Thickness        2.9903        8.2435      Reject null hypothesis
#    Insulin               6.914         6.5582      Reject null hypothesis

# %%
#split x and y
x=df.drop(columns=['Outcome'])
y=df['Outcome']

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)
x_scaled
# Out:
# array([[-0.5153943 ,  0.52455322, -0.86930967, ...,  0.13282408,
#         -1.06324616,  1.18042417],
#        [-1.12049474, -1.1597562 ,  0.80477375, ...,  0.77273898,
#         -0.7355513 , -0.85632626],
#        [-1.12049474,  0.74288962, -0.03226796, ...,  1.60741059,
#          0.49175869, -0.17740945],
#        ...,
#        [ 0.69480658, -1.12856529,  0.46995707, ..., -0.20104457,
#         -0.27492362,  0.75610116],
#        [-1.12049474,  0.24383498,  3.14849054, ...,  4.79307391,
#         -0.46968566, -0.60173245],
#        [-0.5153943 , -1.25332895, -0.03226796, ..., -0.3540677 ,
#          0.23516743, -0.68659705]])

# %%
df['Glucose'].mean
# Out:
# <bound method Series.mean of 0       138
# 1        84
# 2       145
# 3       135
# 4       139
#        ...
# 1995     75
# 1996    179
# 1997     85
# 1998    129
# 1999     81
# Name: Glucose, Length: 2000, dtype: int64>

# %%
x.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000     2000.00000  2000.000000
# mean      3.703500   121.182500      72.385500       27.52450    99.374000
# std       3.306063    32.068636      11.949824        9.56374    98.438245
# min       0.000000     0.000000      24.000000        7.00000    14.000000
# 25%       1.000000    99.000000      64.000000       23.00000    40.000000
# 50%       3.000000   117.000000      72.000000       23.00000    40.000000
# 75%       6.000000   141.000000      80.000000       32.00000   130.000000
# max      17.000000   199.000000     122.000000      110.00000   744.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  2000.000000               2000.000000  2000.000000
# mean     32.645200                  0.470930    33.090500
# std       7.190254                  0.323553    11.786423
# min      18.200000                  0.078000    21.000000
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
norm=MinMaxScaler()
x_scaled_norm=norm.fit_transform(x)
x_scaled_norm=pd.DataFrame(x_scaled_norm,columns=x.columns)
x_scaled_norm.describe()
# Out:
#        Pregnancies      Glucose  BloodPressure  SkinThickness      Insulin  \
# count  2000.000000  2000.000000    2000.000000    2000.000000  2000.000000
# mean      0.217853     0.608957       0.493730       0.199267     0.116951
# std       0.194474     0.161149       0.121937       0.092852     0.134847
# min       0.000000     0.000000       0.000000       0.000000     0.000000
# 25%       0.058824     0.497487       0.408163       0.155340     0.035616
# 50%       0.176471     0.587940       0.489796       0.155340     0.035616
# 75%       0.352941     0.708543       0.571429       0.242718     0.158904
# max       1.000000     1.000000       1.000000       1.000000     1.000000
#
#                BMI  DiabetesPedigreeFunction          Age
# count  2000.000000               2000.000000  2000.000000
# mean      0.231494                  0.167775     0.201508
# std       0.115228                  0.138152     0.196440
# min       0.000000                  0.000000     0.000000
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
error_rate=[]
for i in range(1,11):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred_i=knn.predict(x_test)
    error_rate.append({i:np.mean(pred_i!=y_test)})

# %%
error_rate
# Out:
# [{1: np.float64(0.036)},
#  {2: np.float64(0.118)},
#  {3: np.float64(0.158)},
#  {4: np.float64(0.188)},
#  {5: np.float64(0.186)},
#  {6: np.float64(0.202)},
#  {7: np.float64(0.188)},
#  {8: np.float64(0.216)},
#  {9: np.float64(0.192)},
#  {10: np.float64(0.204)}]
